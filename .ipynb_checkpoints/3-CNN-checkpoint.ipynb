# %% [markdown]
# # CNN

# %%
import torch
from torch import nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torchvision
import torchvision.models #pretrained models
import torchvision.datasets # some datasets
import torchvision.transforms #manipulate our data

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# !nvidia-smi
# Out:
# Wed May 20 17:34:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.58.04              Driver Version: 596.21         CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...    On  |   00000000:F3:00.0 Off |                  N/A |
# | N/A   39C    P8              3W /   39W |    1282MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A             585      C   /python3.11                           N/A      |
# |    0   N/A  N/A             614      C   /python3.11                           N/A      |
# |    0   N/A  N/A            2360      C   /python3.11                           N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
train_data = torchvision.datasets.FashionMNIST(
    root = "data", #where to dowwnload data
    train = True,
    download=True,
    transform = torchvision.transform.ToTensor(),
    target_transform=None
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 train_data = torchvision.datasets.FashionMNIST()
#
# TypeError: MNIST.__init__() missing 1 required positional argument: 'root'
