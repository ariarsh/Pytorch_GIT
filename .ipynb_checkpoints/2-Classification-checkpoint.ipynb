# %% [markdown]
# # Classification

# %% [markdown]
# Output Layer Activation: binary(0,1) -> sigmoid ,   binary(-1,1) -> tanh ,   multiclass -> softmax
#
# Hidden Layer Activation: Relu
#
# LossFunction -> binary cross entropy (BCE), BCEWithlogit (has built-in sigmoid), cross entropy(for non-binary)
#
# How to get label in binary classification -> round the sigmoid of the logits
#
# How to get label in multi-class classification -> argmax of softmax of the logits
#
# Optimiser -> SGD and Adam

# %%
import torch
import sklearn
from torch import nn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torchmetrics

# %%
X,y = sklearn.datasets.make_moons(n_samples=1000 , shuffle=True, noise=0.2, random_state=42)

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
df = pd.DataFrame({"X[1]":X[:,0],"X[2]":X[:,1],"y":y[:]})
df.head(10)
# Out:
#        X[1]      X[2]  y
# 0 -0.111667  0.520224  1
# 1  1.142650 -0.342577  1
# 2  0.795558 -0.011442  1
# 3  0.111827 -0.551932  1
# 4 -0.816466  0.543996  0
# 5  0.662510 -0.084356  1
# 6  0.274510 -0.189904  1
# 7 -0.115556  0.535912  1
# 8  1.572369 -0.335447  1
# 9  0.763990  0.962359  0

# %%
plt.figure(figsize=(6,5))
plt.scatter(X[:,0],X[:,1],c=y)

# %%
X = torch.from_numpy(X).type(torch.float)
y = torch.from_numpy(y).type(torch.float)
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X,y,test_size=0.2, shuffle=True,random_state=42)

# %%
plt.figure(figsize = (12,5))
plt.subplot(1,2,1)
plt.scatter(X_train[:,0],X_train[:,1],c=y_train)
plt.title("Train data")
plt.subplot(1,2,2)
plt.scatter(X_test[:,0],X_test[:,1],c=y_test)
plt.title("Test data")
# Out:
# Text(0.5, 1.0, 'Test data')

# %%
class Model(nn.Module):
    def __init__(self):
        super().__init__()
        self.Layer1 = nn.Linear(2,32)
        self.Layer2 = nn.Linear(32,32)
        self.Layer3 = nn.Linear(32,32)
        self.Layer4 = nn.Linear(32,1)
        self.Relu = nn.ReLU()

    def forward(self,X):
        return self.Layer4(self.Relu(self.Layer3(self.Relu(self.Layer2(self.Relu(self.Layer1(X)))))))


device = "cuda" if torch.cuda.is_available() else "cpu"
MyModel = Model().to(device)
device
# Out:
# 'cuda'

# %%
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)
loss_fn = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(params=MyModel.parameters(), lr=0.01)

# %%
epochs = 10000
torch.manual_seed(42)
torch.cuda.manual_seed(42)
for epoch in range(epochs):
    MyModel.train()
    y_pred = MyModel(X_train)
    loss = loss_fn(y_pred.squeeze(),y_train)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    MyModel.eval()
    with torch.inference_mode():
        y_pred_test = MyModel(X_test)
        test_loss = loss_fn(y_pred_test.squeeze(),y_test)
        if epoch%1000==0:
            print(f"epoch={epoch}, train_loss={loss}, test_loss={test_loss}")
# Out:
# epoch=0, train_loss=0.6921839714050293, test_loss=0.6915891766548157
# epoch=1000, train_loss=0.2872505486011505, test_loss=0.2904384434223175
# epoch=2000, train_loss=0.22871999442577362, test_loss=0.21781966090202332
# epoch=3000, train_loss=0.16337594389915466, test_loss=0.14620202779769897
# epoch=4000, train_loss=0.10981996357440948, test_loss=0.09112739562988281
# epoch=5000, train_loss=0.08819195628166199, test_loss=0.06766095757484436
# epoch=6000, train_loss=0.0790262296795845, test_loss=0.057869233191013336
# epoch=7000, train_loss=0.074515700340271, test_loss=0.05325615778565407
# epoch=8000, train_loss=0.07136719673871994, test_loss=0.05042701214551926
# epoch=9000, train_loss=0.06952348351478577, test_loss=0.04835880547761917

# %%
MyModel.eval()
with torch.inference_mode():
    y_test_pred = MyModel(X_test[:10])
    y_test_pred = torch.round(torch.sigmoid(y_test_pred))

print(f"X:\n\t {X_test[:10]}")
print(f"real label:\n\t{y_test_pred.T}")
print(f"model prediction:\n\t{y_test[:10]}")
Conf = torchmetrics.classification.ConfusionMatrix(task="BINARY").to(device)
print(f"Confusion Matrix:\n\t{Conf(y_pred_test.squeeze(),y_test)}")
# Out:
# X:
# 	 tensor([[ 0.6248, -0.4549],
#         [ 1.1254,  0.4677],
#         [ 1.3842, -0.3646],
#         [ 0.8931,  0.9734],
#         [ 1.7039, -0.4324],
#         [ 2.0486, -0.2413],
#         [ 1.1716,  0.1821],
#         [ 1.1360,  0.1136],
#         [ 1.2792, -1.0017],
#         [ 0.6679,  0.5247]], device='cuda:0')
# real label:
# 	tensor([[1., 0., 1., 0., 1., 1., 0., 0., 1., 0.]], device='cuda:0')
# model prediction:
# 	tensor([1., 0., 1., 0., 1., 1., 0., 0., 1., 0.], device='cuda:0')
# Confusion Matrix:
# 	tensor([[98,  2],
#         [ 4, 96]], device='cuda:0')

# %% [markdown]
# ## Metrix Digest
#
# ### Confussion matrix
#
# |                | Predicted Positive | Predicted Negative |
# |----------------|-------------------|-------------------|
# | Actual Positive | TP | FN |
# | Actual Negative | FP | TN |
#
# ---
#
# ### Accuracy
#
# overall correctness
# $$
# \text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN}
# $$
#
# ---
#
# ### Precision
#
# reliability of positive predictions
#
# $$
# \text{Precision} = \frac{TP}{TP + FP}
# $$
#
# ---
#
# ### Recall
#
# ability to find actual positives
# $$
# \text{Recall} = \frac{TP}{TP + FN}
# $$
#
# ---
#
# ### F1-score
#
# balance between precision and recall:
#
# $$
# F_1 = 2 \frac{\text{Precision} \times \text{Recall}}
# {\text{Precision} + \text{Recall}}
# $$
